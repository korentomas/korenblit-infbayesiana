# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('predicciones_atp_con_kelly.csv')
df
# Out:
#              date         winner           loser  m_winner   m_loser  \
# 0      2000-01-03     Dosedel S.     Ljubicic I.  0.000000  0.000000
# 1      2000-01-03     Enqvist T.      Clement A.  0.000000  0.000000
# 2      2000-01-03      Escude N.   Baccanello P.  0.000000  0.000000
# 3      2000-01-03     Federer R.  Knippschild J.  0.000000  0.000000
# 4      2000-01-03    Fromberg R.   Woodbridge T.  0.000000  0.000000
# ...           ...            ...             ...       ...       ...
# 54903  2019-11-15      Nadal R.    Tsitsipas S.  -0.562822  2.271221
# 54904  2019-11-15     Zverev A.     Medvedev D.   0.562822 -2.271221
# 54905  2019-11-16  Tsitsipas S.      Federer R.   0.736864  2.844917
# 54906  2019-11-16      Thiem D.       Zverev A.   2.368925  0.758517
# 54907  2019-11-17  Tsitsipas S.        Thiem D.   1.889664  2.233248
#
#        s_winner   s_loser  b_winner  b_loser  bankroll
# 0      2.500000  2.500000       NaN      NaN    1000.0
# 1      2.500000  2.500000       NaN      NaN    1000.0
# 2      2.500000  2.500000       NaN      NaN    1000.0
# 3      2.500000  2.500000       NaN      NaN    1000.0
# 4      2.500000  2.500000       NaN      NaN    1000.0
# ...         ...       ...       ...      ...       ...
# 54903  1.692036  1.863906      1.44     2.75       NaN
# 54904  1.692036  1.863906      1.90     1.90       NaN
# 54905  1.359801  1.192065      3.50     1.30       NaN
# 54906  1.167199  1.372679      1.80     2.00       NaN
# 54907  1.154276  1.060549      2.00     1.80       NaN
#
# [54908 rows x 10 columns]

# %%
df = df.loc[df['bankroll'] > 0].copy()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert date column to datetime
df['date'] = pd.to_datetime(df['date'])

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['date'], np.log(df['bankroll']))
plt.title("log(Bankroll) Growth Over Time")
plt.xlabel("Date") 
plt.ylabel("log(Bankroll)")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
